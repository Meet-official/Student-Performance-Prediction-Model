# %% [markdown]
# ## **Student Academic - Performance Predictor**

# %%
import pandas as pd

# %%
student = pd.read_csv("student-data.csv")

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         1044 non-null   object
#  1   age         1044 non-null   int64
#  2   Medu        1044 non-null   int64
#  3   Fedu        1044 non-null   int64
#  4   traveltime  1044 non-null   int64
#  5   studytime   1044 non-null   int64
#  6   failures    1044 non-null   int64
#  7   schoolsup   1044 non-null   object
#  8   famsup      1044 non-null   object
#  9   paid        1044 non-null   object
#  10  activities  1044 non-null   object
#  11  higher      1044 non-null   object
#  12  internet    1044 non-null   object
#  13  romantic    1044 non-null   object
#  14  famrel      1044 non-null   int64
#  15  freetime    1044 non-null   int64
#  16  goout       1044 non-null   int64
#  17  health      1044 non-null   int64
#  18  absences    1044 non-null   int64
#  19  G1          1044 non-null   int64
#  20  G2          1044 non-null   int64
#  21  G3          1044 non-null   int64
# dtypes: int64(14), object(8)
# memory usage: 179.6+ KB

# %%
student.describe()
# Out:
#                age         Medu         Fedu   traveltime    studytime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     2.603448     2.387931     1.522989     1.970307
# std       1.239975     1.124907     1.099938     0.731727     0.834353
# min      15.000000     0.000000     0.000000     1.000000     1.000000
# 25%      16.000000     2.000000     1.000000     1.000000     1.000000
# 50%      17.000000     3.000000     2.000000     1.000000     2.000000
# 75%      18.000000     4.000000     3.000000     2.000000     2.000000
# max      22.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout       health  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.264368     3.935824     3.201149     3.156130     3.543103
# std       0.656142     0.933401     1.031507     1.152575     1.424703
# min       0.000000     1.000000     1.000000     1.000000     1.000000
# 25%       0.000000     4.000000     3.000000     2.000000     3.000000
# 50%       0.000000     4.000000     3.000000     3.000000     4.000000
# 75%       0.000000     5.000000     4.000000     4.000000     5.000000
# max       3.000000     5.000000     5.000000     5.000000     5.000000
#
#           absences           G1           G2           G3
# count  1044.000000  1044.000000  1044.000000  1044.000000
# mean      4.434866    11.213602    11.246169    11.341954
# std       6.210017     2.983394     3.285071     3.864796
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     9.000000     9.000000    10.000000
# 50%       2.000000    11.000000    11.000000    11.000000
# 75%       6.000000    13.000000    13.000000    14.000000
# max      75.000000    19.000000    19.000000    20.000000

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
student.hist(bins = 50, figsize = (20, 15))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'Medu'}>,
#         <Axes: title={'center': 'Fedu'}>,
#         <Axes: title={'center': 'traveltime'}>],
#        [<Axes: title={'center': 'studytime'}>,
#         <Axes: title={'center': 'failures'}>,
#         <Axes: title={'center': 'famrel'}>,
#         <Axes: title={'center': 'freetime'}>],
#        [<Axes: title={'center': 'goout'}>,
#         <Axes: title={'center': 'health'}>,
#         <Axes: title={'center': 'absences'}>,
#         <Axes: title={'center': 'G1'}>],
#        [<Axes: title={'center': 'G2'}>, <Axes: title={'center': 'G3'}>,
#         <Axes: >, <Axes: >]], dtype=object)

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         1044 non-null   object
#  1   age         1044 non-null   int64
#  2   Medu        1044 non-null   int64
#  3   Fedu        1044 non-null   int64
#  4   traveltime  1044 non-null   int64
#  5   studytime   1044 non-null   int64
#  6   failures    1044 non-null   int64
#  7   schoolsup   1044 non-null   object
#  8   famsup      1044 non-null   object
#  9   paid        1044 non-null   object
#  10  activities  1044 non-null   object
#  11  higher      1044 non-null   object
#  12  internet    1044 non-null   object
#  13  romantic    1044 non-null   object
#  14  famrel      1044 non-null   int64
#  15  freetime    1044 non-null   int64
#  16  goout       1044 non-null   int64
#  17  health      1044 non-null   int64
#  18  absences    1044 non-null   int64
#  19  G1          1044 non-null   int64
#  20  G2          1044 non-null   int64
#  21  G3          1044 non-null   int64
# dtypes: int64(14), object(8)
# memory usage: 179.6+ KB

# %%
import numpy as np

# %%
student['sex'] = student['sex'].map({'M': 1, 'F': 0})
student['schoolsup'] = student['schoolsup'].map({'yes': 1, 'no': 0})
student['famsup'] = student['famsup'].map({'yes': 1, 'no': 0})
student['paid'] = student['paid'].map({'yes': 1, 'no': 0})
student['activities'] = student['activities'].map({'yes': 1, 'no': 0})
student['higher'] = student['higher'].map({'yes': 0, 'no': 1})
student['internet'] = student['internet'].map({'yes': 0, 'no': 1})
student['romantic'] = student['romantic'].map({'yes': 0, 'no': 1})

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         1044 non-null   int64
#  1   age         1044 non-null   int64
#  2   Medu        1044 non-null   int64
#  3   Fedu        1044 non-null   int64
#  4   traveltime  1044 non-null   int64
#  5   studytime   1044 non-null   int64
#  6   failures    1044 non-null   int64
#  7   schoolsup   1044 non-null   int64
#  8   famsup      1044 non-null   int64
#  9   paid        1044 non-null   int64
#  10  activities  1044 non-null   int64
#  11  higher      1044 non-null   int64
#  12  internet    1044 non-null   int64
#  13  romantic    1044 non-null   int64
#  14  famrel      1044 non-null   int64
#  15  freetime    1044 non-null   int64
#  16  goout       1044 non-null   int64
#  17  health      1044 non-null   int64
#  18  absences    1044 non-null   int64
#  19  G1          1044 non-null   int64
#  20  G2          1044 non-null   int64
#  21  G3          1044 non-null   int64
# dtypes: int64(22)
# memory usage: 179.6 KB

# %%
corr_matrix = student.corr()
corr_matrix['G3'].sort_values(ascending = False)
# Out:
# G3            1.000000
# G2            0.910743
# G1            0.809142
# Medu          0.201472
# studytime     0.161629
# Fedu          0.159796
# romantic      0.098363
# famrel        0.054461
# activities    0.033998
# famsup        0.013313
# sex          -0.031472
# absences     -0.045671
# paid         -0.049388
# freetime     -0.064890
# schoolsup    -0.079346
# health       -0.080079
# goout        -0.097877
# traveltime   -0.102627
# internet     -0.107064
# age          -0.125282
# higher       -0.236578
# failures     -0.383145
# Name: G3, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ["G3", "G2", "G1", "failures"]
scatter_matrix(student[attributes], figsize = (12, 8))
# Out:
# array([[<Axes: xlabel='G3', ylabel='G3'>,
#         <Axes: xlabel='G2', ylabel='G3'>,
#         <Axes: xlabel='G1', ylabel='G3'>,
#         <Axes: xlabel='failures', ylabel='G3'>],
#        [<Axes: xlabel='G3', ylabel='G2'>,
#         <Axes: xlabel='G2', ylabel='G2'>,
#         <Axes: xlabel='G1', ylabel='G2'>,
#         <Axes: xlabel='failures', ylabel='G2'>],
#        [<Axes: xlabel='G3', ylabel='G1'>,
#         <Axes: xlabel='G2', ylabel='G1'>,
#         <Axes: xlabel='G1', ylabel='G1'>,
#         <Axes: xlabel='failures', ylabel='G1'>],
#        [<Axes: xlabel='G3', ylabel='failures'>,
#         <Axes: xlabel='G2', ylabel='failures'>,
#         <Axes: xlabel='G1', ylabel='failures'>,
#         <Axes: xlabel='failures', ylabel='failures'>]], dtype=object)

# %%
# G3 - G2
# G3 - G1
# G2 - G1
# G3 - failures

student["score_trend"] = student["G2"] - student["G1"]
student["desire_gap"] = (student["higher"]) - (student["G2"] / 20)
student["travel_study_gap"] = student["traveltime"] - student["studytime"]
student["score_desire"] = student["score_trend"] - student["desire_gap"]
student["parent_studytime"] = ((student["Medu"] + student["Fedu"])/2) * student["studytime"]

# %%
corr_matrix = student.corr()
corr_matrix['G3'].sort_values(ascending = False)
# Out:
# G3                  1.000000
# G2                  0.910743
# G1                  0.809142
# score_desire        0.441343
# score_trend         0.341705
# parent_studytime    0.220280
# Medu                0.201472
# studytime           0.161629
# Fedu                0.159796
# romantic            0.098363
# famrel              0.054461
# activities          0.033998
# famsup              0.013313
# sex                -0.031472
# absences           -0.045671
# paid               -0.049388
# freetime           -0.064890
# schoolsup          -0.079346
# health             -0.080079
# goout              -0.097877
# traveltime         -0.102627
# internet           -0.107064
# age                -0.125282
# travel_study_gap   -0.181990
# higher             -0.236578
# failures           -0.383145
# desire_gap         -0.602782
# Name: G3, dtype: float64

# %%
attributes = ["G3", "G2", "G1", "score_desire", "score_trend", "parent_studytime", "desire_gap"]
scatter_matrix(student[attributes], figsize = (12, 8))
# Out:
# array([[<Axes: xlabel='G3', ylabel='G3'>,
#         <Axes: xlabel='G2', ylabel='G3'>,
#         <Axes: xlabel='G1', ylabel='G3'>,
#         <Axes: xlabel='score_desire', ylabel='G3'>,
#         <Axes: xlabel='score_trend', ylabel='G3'>,
#         <Axes: xlabel='parent_studytime', ylabel='G3'>,
#         <Axes: xlabel='desire_gap', ylabel='G3'>],
#        [<Axes: xlabel='G3', ylabel='G2'>,
#         <Axes: xlabel='G2', ylabel='G2'>,
#         <Axes: xlabel='G1', ylabel='G2'>,
#         <Axes: xlabel='score_desire', ylabel='G2'>,
#         <Axes: xlabel='score_trend', ylabel='G2'>,
#         <Axes: xlabel='parent_studytime', ylabel='G2'>,
#         <Axes: xlabel='desire_gap', ylabel='G2'>],
#        [<Axes: xlabel='G3', ylabel='G1'>,
#         <Axes: xlabel='G2', ylabel='G1'>,
#         <Axes: xlabel='G1', ylabel='G1'>,
#         <Axes: xlabel='score_desire', ylabel='G1'>,
#         <Axes: xlabel='score_trend', ylabel='G1'>,
#         <Axes: xlabel='parent_studytime', ylabel='G1'>,
#         <Axes: xlabel='desire_gap', ylabel='G1'>],
#        [<Axes: xlabel='G3', ylabel='score_desire'>,
#         <Axes: xlabel='G2', ylabel='score_desire'>,
#         <Axes: xlabel='G1', ylabel='score_desire'>,
#         <Axes: xlabel='score_desire', ylabel='score_desire'>,
#         <Axes: xlabel='score_trend', ylabel='score_desire'>,
#         <Axes: xlabel='parent_studytime', ylabel='score_desire'>,
#         <Axes: xlabel='desire_gap', ylabel='score_desire'>],
#        [<Axes: xlabel='G3', ylabel='score_trend'>,
#         <Axes: xlabel='G2', ylabel='score_trend'>,
#         <Axes: xlabel='G1', ylabel='score_trend'>,
#         <Axes: xlabel='score_desire', ylabel='score_trend'>,
#         <Axes: xlabel='score_trend', ylabel='score_trend'>,
#         <Axes: xlabel='parent_studytime', ylabel='score_trend'>,
#         <Axes: xlabel='desire_gap', ylabel='score_trend'>],
#        [<Axes: xlabel='G3', ylabel='parent_studytime'>,
#         <Axes: xlabel='G2', ylabel='parent_studytime'>,
#         <Axes: xlabel='G1', ylabel='parent_studytime'>,
#         <Axes: xlabel='score_desire', ylabel='parent_studytime'>,
#         <Axes: xlabel='score_trend', ylabel='parent_studytime'>,
#         <Axes: xlabel='parent_studytime', ylabel='parent_studytime'>,
#         <Axes: xlabel='desire_gap', ylabel='parent_studytime'>],
#        [<Axes: xlabel='G3', ylabel='desire_gap'>,
#         <Axes: xlabel='G2', ylabel='desire_gap'>,
#         <Axes: xlabel='G1', ylabel='desire_gap'>,
#         <Axes: xlabel='score_desire', ylabel='desire_gap'>,
#         <Axes: xlabel='score_trend', ylabel='desire_gap'>,
#         <Axes: xlabel='parent_studytime', ylabel='desire_gap'>,
#         <Axes: xlabel='desire_gap', ylabel='desire_gap'>]], dtype=object)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
student["G3_cat"] = pd.cut(student["G3"],
                           bins=[-1, 5, 10, 15, 20],
                           labels=[0, 1, 2, 3])

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_idx, test_idx in split.split(student, student["G3_cat"]):
    strat_train_set = student.loc[train_idx]
    strat_test_set = student.loc[test_idx]

# Remove col
for set_ in (strat_train_set, strat_test_set):
    set_.drop("G3_cat", axis=1, inplace=True)

# %%
features = [
    "G1", "G2",                                        # Strong predictors
    "score_desire", "score_trend",                     # Engineered high-corr features
    "parent_studytime", "studytime", "Medu", "Fedu",   # Parental & study info
    "travel_study_gap", "failures", "higher",          # Negatively correlated, but meaningful
    "desire_gap"                                       # Engineered negative-corr
]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_scaled = scaler.fit_transform(strat_train_set[features])
test_scaled = scaler.transform(strat_test_set[features])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Train
model = LinearRegression()
# model = DecisionTreeRegressor()
# model = SVR()
# model = RandomForestRegressor()

model.fit(train_scaled, strat_train_set["G3"])

# Predict
preds = model.predict(test_scaled)

# Evaluate
r2 = r2_score(strat_test_set["G3"], preds)
mse = mean_squared_error(strat_test_set["G3"], preds)
rmse = mse ** 0.5

print("📊 Final Evaluation on Test Data:")
print("R² Score:", r2)
print("RMSE:", rmse)
# Out:
# 📊 Final Evaluation on Test Data:
# R² Score: 0.8626851841042196
# RMSE: 1.4516456892112297

# %%
from joblib import dump, load

dump(model, 'Student_Performance.joblib')
# Out:
# ['Student_Performance.joblib']

# %%
# model = load('Real-Estate.joblib')

# %%
import pandas as pd

features_vector = [
    12,     # G1
    13,     # G2
    0.7,    # score_desire
    1.0,    # score_trend (G2 - G1)
    6.0,    # parent_studytime (e.g., avg(3,3) × studytime 2)
    2,      # studytime
    3,      # Medu
    3,      # Fedu
    0,      # travel_study_gap (e.g., travel and study both = 2)
    0,      # failures
    1,      # higher (1 = wants higher education)
    0.35    # desire_gap (1 - G2/20 → 1 - 13/20 = 0.35)
]

# Use the same feature names used during training
feature_names = [
    "G1", "G2", "score_desire", "score_trend", "parent_studytime",
    "studytime", "Medu", "Fedu", "travel_study_gap", "failures",
    "higher", "desire_gap"
]

# Wrap into a DataFrame
input_df = pd.DataFrame([features_vector], columns=feature_names)

# Scale it using StandardScaler
input_scaled = scaler.transform(input_df)

# Predict
predicted_g3 = model.predict(input_scaled)[0]
print(f"📘 Predicted Final Grade (G3): {predicted_g3:.2f}")
# Out:
# 📘 Predicted Final Grade (G3): 13.32
